# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting filelock (from torch)
#   Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\venv\lib\site-packages (from torch) (4.13.1)
# Collecting networkx (from torch)
#   Using cached https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch)
#   Using cached https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Using cached https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: numpy in .\venv\lib\site-packages (from torchvision) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in .\venv\lib\site-packages (from torchvision) (11.1.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Using cached https://download.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp310-cp310-win_amd64.whl (2532.3 MB)
# Using cached https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp310-cp310-win_amd64.whl (6.1 MB)
# Using cached https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp310-cp310-win_amd64.whl (4.2 MB)
# Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl (1.7 MB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision, torchaudio
# Successfully installed MarkupSafe-2.1.5 filelock-3.13.1 fsspec-2024.6.1 jinja2-3.1.4 mpmath-1.3.0 networkx-3.3 sympy-1.13.1 torch-2.6.0+cu124 torchaudio-2.6.0+cu124 torchvision-0.21.0+cu124

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in .\venv\lib\site-packages (from -r requirements.txt (line 1)) (2.2.4)
# Requirement already satisfied: pandas in .\venv\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: matplotlib in .\venv\lib\site-packages (from -r requirements.txt (line 3)) (3.10.1)
# Requirement already satisfied: seaborn in .\venv\lib\site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: nltk in .\venv\lib\site-packages (from -r requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: regex in .\venv\lib\site-packages (from -r requirements.txt (line 6)) (2024.11.6)
# Requirement already satisfied: scikit-learn in .\venv\lib\site-packages (from -r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: from-root in .\venv\lib\site-packages (from -r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: google-cloud-storage in .\venv\lib\site-packages (from -r requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: python-dotenv in .\venv\lib\site-packages (from -r requirements.txt (line 11)) (1.1.0)
# Collecting rouge_score (from -r requirements.txt (line 12))
#   Using cached rouge_score-0.1.2-py3-none-any.whl
# Collecting sentencepiece (from -r requirements.txt (line 13))
#   Using cached sentencepiece-0.2.0-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Collecting evaluate (from -r requirements.txt (line 14))
#   Using cached evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: protobuf in .\venv\lib\site-packages (from -r requirements.txt (line 15)) (6.30.2)
# Collecting tiktoken (from -r requirements.txt (line 16))
#   Using cached tiktoken-0.9.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting transformers[torch] (from -r requirements.txt (line 8))
#   Downloading transformers-4.51.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: click in .\venv\lib\site-packages (from nltk->-r requirements.txt (line 5)) (8.1.8)
# Requirement already satisfied: joblib in .\venv\lib\site-packages (from nltk->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: tqdm in .\venv\lib\site-packages (from nltk->-r requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in .\venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in .\venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from transformers[torch]->-r requirements.txt (line 8)) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers[torch]->-r requirements.txt (line 8))
#   Downloading huggingface_hub-0.30.1-py3-none-any.whl.metadata (13 kB)
# Collecting pyyaml>=5.1 (from transformers[torch]->-r requirements.txt (line 8))
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests in .\venv\lib\site-packages (from transformers[torch]->-r requirements.txt (line 8)) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers[torch]->-r requirements.txt (line 8))
#   Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers[torch]->-r requirements.txt (line 8))
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: torch>=2.0 in .\venv\lib\site-packages (from transformers[torch]->-r requirements.txt (line 8)) (2.6.0+cu124)
# Collecting accelerate>=0.26.0 (from transformers[torch]->-r requirements.txt (line 8))
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in .\venv\lib\site-packages (from google-cloud-storage->-r requirements.txt (line 10)) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in .\venv\lib\site-packages (from google-cloud-storage->-r requirements.txt (line 10)) (2.24.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in .\venv\lib\site-packages (from google-cloud-storage->-r requirements.txt (line 10)) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in .\venv\lib\site-packages (from google-cloud-storage->-r requirements.txt (line 10)) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in .\venv\lib\site-packages (from google-cloud-storage->-r requirements.txt (line 10)) (1.7.1)
# Collecting absl-py (from rouge_score->-r requirements.txt (line 12))
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.14.0 in .\venv\lib\site-packages (from rouge_score->-r requirements.txt (line 12)) (1.17.0)
# Collecting datasets>=2.0.0 (from evaluate->-r requirements.txt (line 14))
#   Using cached datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting dill (from evaluate->-r requirements.txt (line 14))
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from evaluate->-r requirements.txt (line 14))
#   Using cached xxhash-3.5.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess (from evaluate->-r requirements.txt (line 14))
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in .\venv\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate->-r requirements.txt (line 14)) (2024.6.1)
# Requirement already satisfied: psutil in .\venv\lib\site-packages (from accelerate>=0.26.0->transformers[torch]->-r requirements.txt (line 8)) (7.0.0)
# Collecting pyarrow>=15.0.0 (from datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached pyarrow-19.0.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting dill (from evaluate->-r requirements.txt (line 14))
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate->-r requirements.txt (line 14))
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting aiohttp (from datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Downloading aiohttp-3.11.16-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in .\venv\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->-r requirements.txt (line 10)) (1.69.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in .\venv\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->-r requirements.txt (line 10)) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in .\venv\lib\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->-r requirements.txt (line 10)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\venv\lib\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->-r requirements.txt (line 10)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in .\venv\lib\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->-r requirements.txt (line 10)) (4.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\venv\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers[torch]->-r requirements.txt (line 8)) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests->transformers[torch]->-r requirements.txt (line 8)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests->transformers[torch]->-r requirements.txt (line 8)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests->transformers[torch]->-r requirements.txt (line 8)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests->transformers[torch]->-r requirements.txt (line 8)) (2025.1.31)
# Requirement already satisfied: networkx in .\venv\lib\site-packages (from torch>=2.0->transformers[torch]->-r requirements.txt (line 8)) (3.3)
# Requirement already satisfied: jinja2 in .\venv\lib\site-packages (from torch>=2.0->transformers[torch]->-r requirements.txt (line 8)) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in .\venv\lib\site-packages (from torch>=2.0->transformers[torch]->-r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\lib\site-packages (from sympy==1.13.1->torch>=2.0->transformers[torch]->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm->nltk->-r requirements.txt (line 5)) (0.4.6)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached frozenlist-1.5.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Downloading multidict-6.3.2-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Using cached propcache-0.3.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 14))
#   Downloading yarl-1.19.0-cp310-cp310-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in .\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage->-r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\lib\site-packages (from jinja2->torch>=2.0->transformers[torch]->-r requirements.txt (line 8)) (2.1.5)
# Using cached sentencepiece-0.2.0-cp310-cp310-win_amd64.whl (991 kB)
# Using cached evaluate-0.4.3-py3-none-any.whl (84 kB)
# Using cached tiktoken-0.9.0-cp310-cp310-win_amd64.whl (894 kB)
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
# Using cached datasets-3.5.0-py3-none-any.whl (491 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading huggingface_hub-0.30.1-py3-none-any.whl (481 kB)
# Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading transformers-4.51.0-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.4 MB 4.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/10.4 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.4 MB 4.3 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.4 MB 4.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.4 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.2/10.4 MB 4.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.4 MB 4.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.8/10.4 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.4 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 7.9/10.4 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.2/10.4 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 4.0 MB/s eta 0:00:00
# Using cached xxhash-3.5.0-cp310-cp310-win_amd64.whl (30 kB)
# Downloading aiohttp-3.11.16-cp310-cp310-win_amd64.whl (442 kB)
# Using cached pyarrow-19.0.1-cp310-cp310-win_amd64.whl (25.3 MB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.5.0-cp310-cp310-win_amd64.whl (51 kB)
# Downloading multidict-6.3.2-cp310-cp310-win_amd64.whl (38 kB)
# Using cached propcache-0.3.1-cp310-cp310-win_amd64.whl (45 kB)
# Downloading yarl-1.19.0-cp310-cp310-win_amd64.whl (92 kB)
# Installing collected packages: sentencepiece, xxhash, safetensors, pyyaml, pyarrow, propcache, multidict, frozenlist, dill, attrs, async-timeout, aiohappyeyeballs, absl-py, yarl, tiktoken, multiprocess, huggingface-hub, aiosignal, tokenizers, rouge_score, aiohttp, accelerate, transformers, datasets, evaluate
# Successfully installed absl-py-2.2.2 accelerate-1.6.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.16 aiosignal-1.3.2 async-timeout-5.0.1 attrs-25.3.0 datasets-3.5.0 dill-0.3.8 evaluate-0.4.3 frozenlist-1.5.0 huggingface-hub-0.30.1 multidict-6.3.2 multiprocess-0.70.16 propcache-0.3.1 pyarrow-19.0.1 pyyaml-6.0.2 rouge_score-0.1.2 safetensors-0.5.3 sentencepiece-0.2.0 tiktoken-0.9.0 tokenizers-0.21.1 transformers-4.51.0 xxhash-3.5.0 yarl-1.19.0
